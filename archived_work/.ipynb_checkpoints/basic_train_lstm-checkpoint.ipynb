# %% [markdown]
# # Model 2 - LSTM: Simple neural network with only one branch with LSTM.

# %%
import pandas as pd
import tflearn as tf
import numpy as np
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from tflearn.data_utils import to_categorical, pad_sequences
import os

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)

# %%
def read_tweet_to_list(positive,full,is_train=True,max_num=None):
    tweets=[]
    base='train_'
    if positive:
        base+='pos'
    else:
        base+='neg'
    if full:
        base+='_full'
    if(is_train==False):
        base='test_data'
    base+='.txt'
    count=0
    max_len=0
    with open('/home/keshav/ML_course/project_text_classification/twitter-datasets/{}'.format(base)) as f:
        for line in f:
            if(len(line)>max_len):
                max_len=len(line)
            tweets.append(''.join(list(filter(lambda x: not x.isdigit(), line))))
            if(max_num):
                count+=1
                if(count>max_num):
                    break
    print ('max len of is_positive:{} tweet is {}'.format(positive,max_len))
    return tweets

# %%
neg_tweets=read_tweet_to_list(False,True,max_num=None)
pos_tweets=read_tweet_to_list(True,True,max_num=None)
test_tweets=read_tweet_to_list(False,False,False,max_num=None)
# Out:
# max len of is_positive:False tweet is 324
# max len of is_positive:True tweet is 402
# max len of is_positive:False tweet is 177

# %%
num_test_tweets=len(test_tweets)
num_train_tweets=len(pos_tweets)+len(neg_tweets)

# %%
print('number of positive tweets are {} and negative tweets are {}'.format(len(pos_tweets),len(neg_tweets)))
print('number of test tweets are {}'.format(len(test_tweets)))
# Out:
# number of positive tweets are 1250000 and negative tweets are 1250000
# number of test tweets are 10000

# %%
df_neg_tweets=pd.DataFrame({'tweet':neg_tweets,'smile':list(np.zeros(len(neg_tweets)))})
df_pos_tweets=pd.DataFrame({'tweet':pos_tweets,'smile':list(np.ones(len(pos_tweets)))})
df_test_tweets=pd.DataFrame({'tweet':test_tweets,'smile':list(np.ones(len(test_tweets)))})

# %%
df_full=pd.concat([df_neg_tweets,df_pos_tweets,df_test_tweets])
df_full.shape
# Out:
# (2510000, 2)

# %%
def generateX_Y(data):
    X, Y = data.drop('smile',1),data['smile']
    Y = to_categorical(Y,nb_classes=2)
    tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)
    vectorizer = CountVectorizer(tokenizer=tknzr.tokenize,min_df=5)
    bag_trainX = vectorizer.fit_transform(X['tweet'])
    features=vectorizer.get_feature_names()
    num_vocab = len(vectorizer.get_feature_names())
    print(vectorizer.get_feature_names())
    bag_of_ids_trainX = {"bag": [], 'max_len': bag_trainX.shape[1]}
    for bag in bag_trainX:
        bag_of_ids_trainX['bag'].append(np.where(bag.toarray() > 0)[1])
    bag_of_ids_trainX['bag'] = pad_sequences(bag_of_ids_trainX['bag'], maxlen=100)

    return bag_of_ids_trainX['bag'], Y,num_vocab,features,vectorizer

# %%
#Generate trainX,trainY,testX,testY

X, Y,num_vocab,features,vectorizer = generateX_Y(df_full)
# Out:
# ['!', '"', '#', '#aaa', '#ab', '#aba', '#abc', '#abdc', '#abfab', '#about', '#aboutme', '#abouttime', '#abovetheinfluence', '#aboyfriendshould', '#abparty', '#abq', '#abuse', '#abvote', '#ac', '#accidentprone', '#accomplished', '#accounting', '#ace', '#aceprimofact', '#acinderellastory', '#actor', '#ad', '#aday', '#add', '#addict', '#addicted', '#addiction', '#addicts', '#addmeranz', '#adelaide', '#adelaidewantstwodconcerts', '#adele', '#admin', '#adobe', '#adoptakuola', '#adorable', '#adrianna', '#adult', '#adultcafe', '#adulthood', '#adventure', '#adventuretime', '#advertising', '#advice', '#af', '#afc', '#afghanistan', '#afl', '#africa', '#again', '#againstbullyingproject', '#agile', '#agirlcandream', '#agony', '#agree', '#agreed', '#agt', '#agt_au', '#ah', '#ahaha', '#ahcj', '#ahh', '#ahhh', '#ahs', '#ai', '#aimulaikontrams', '#aine', '#aintlovecrazy', '#aionetc', '#aionsw', '#airdelays', '#airingnow', '#aitd', '#ak', '#al', '#alakh', '#alaric', '#albarbz', '#alberta', '#album', '#alcohol', '#alcoholic', '#aleaguegf', '#alec', "#alec's", '#alecexposed', '#alevels', '#alex', '#alexisjordanfollow', '#alhamdulillah', '#alicebucketlist', '#alicebungisngis', '#alittlebitofheaven', '#alkhawaja', '#all', '#allah', '#allalone', '#allbad', '#allcapseverything', '#allday', '#allergies', '#allgrownup', '#alllove', '#allnighter', '#allnightlong', '#allrelationshipsneed', '#allsmiles', '#allthingsasian', '#allworknoplay', '#allyourjobs', '#almost', '#almostdone', '#almostthere', '#alone', '#alot', '#already', '#als', '#always', '#am', '#amateur', '#amazayn', '#amazaynmalik', '#amazaynmaliklist', '#amazeballs', '#amazing', '#amazingfriends', '#amazon', '#ambition', '#amen', '#amendment', '#america', '#american', '#americanbandstand', '#americanidol', '#americanpie', '#americanpiereunion', '#americanreunion', '#amillionlights', '#amin', '#amman', '#amreading', '#ams', '#amsp', '#amsterdam', '#amwriting', '#amzn', '#anal', '#analytics', '#and', '#andheridude', '#andpregnant', '#andrewwillbeatthis', '#android', '#androidproblems', '#angel', '#angels', '#angelsandgentlemen', '#angry', '#angryboys', '#angrytweet', '#animal', '#animals', '#animation', '#anime', '#animsabidal', '#anipals', '#anna', '#anniversary', '#annoyed', '#annoying', '#anonymous', '#ansaaa', '#anticucumberday', '#antm', '#anxiety', '#anxious', '#anyone', '#anytakers', '#anything', '#anytime', '#aomf', '#aots', '#apocalyptour', '#app', '#apple', '#appreciate', '#appreciated', '#appreciateit', '#appreciation', '#appreciative', '#apprentice', '#apps', '#april', '#aprilbabies', '#aprilphotoaday', '#aprilrd', '#aprilshowers', '#aprilth', '#apt', '#aquarians', '#aquarius', '#arabrevolution', '#arabsgottalent', '#arcadenext', '#arcadenextlive', '#archiesmission', '#architecture', '#arealgirlfriend', '#argentina', '#arianator', '#arianators', '#aries', '#arizona', '#armeniangenocide', '#army', '#armywives', '#arsenal', '#arsenaltillidie', '#art', '#artist', '#aryana', '#aryanafever', '#asaboyfriend', '#asalways', '#asap', '#asd', '#ashamed', '#asia', '#asiansontwitter', '#asianswantsdtour', '#askali', '#askallegri', '#askben', '#askbrian', '#askcraig', '#askdiggy', '#askdrew', '#asked', '#askfreddie', '#askgazgshore', '#askgi', '#askholly', '#askhp', '#askivyrisejosh', '#askjay', '#askjessiej', '#askkat', '#askkatie', '#askkris', '#askkylie', '#asklux', '#askmatty', '#askmollie', '#asknadine', '#asknancy', '#askpointlessblogtv', '#askprivate', '#askretwittings', '#askscandal', '#asktin', '#asktwitter', '#asktyger', '#askzac', '#askzacefron', '#asot', '#ass', '#assad', '#assange', '#asshole', '#assholes', '#associatedfresh', '#asswednesday', '#astrokhaos', '#astronauts', '#astros', '#asu', '#asusual', '#at', '#atheism', '#atheist', '#athleteproblems', '#athletes', '#athletic', '#athletics', '#atl', '#atlanta', '#atozchallenge', '#atp', '#attaboy', '#attention', '#attentionplease', '#atthebtwballiwant', '#atthesamedamntime', '#attractive', '#atv', '#atx', '#auction', '#augofollow', ...

# %%
X_test=X[num_train_tweets:]
X=X[:num_train_tweets]
Y=Y[:num_train_tweets]

# %%
permute = np.random.permutation(len(X))
X = X[permute]
Y = Y[permute]
fraction_test=0.8
trainX , trainY = X[:int(fraction_test*(len(X)))],Y[:int(fraction_test*(len(Y)))]
testX , testY = X[int(fraction_test*(len(X))):],Y[int(fraction_test*(len(Y))):]

# %%
np.max(X)
# Out:
# 89129

# %%
'''
import pandas as pd
import tflearn as tf
import numpy as np
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from tflearn.data_utils import to_categorical, pad_sequences
'''
import pickle
#trainX,trainY,testX,testY,num_vocab=pickle.load(open('train_test','rb'))
pickle.dump([trainX,trainY,testX,testY,X_test,num_vocab],open('train_test_full_test','wb'))

# %%
#Create SentimentalAnalysis Layer(LSTM)
tensorflow.reset_default_graph()
net = tf.input_data([None, 100] ,name='input_layer')
net = tf.embedding(net, input_dim=num_vocab, output_dim=256,name='embedded_layer')
#net=tf.simple_rnn(net,n_units=512,name='recurrent_layer',activation='relu')
net = tf.lstm(net, 256, dropout = 0.8,name = 'LSTM_layer',return_seq=True)
#net = tf.lstm(net ,256 ,dropout = 0.9 ,name = 'LSTM_layer2')
#net = tf.fully_connected(net, 150, activation='relu',name='first_fc')
#net = tf.fully_connected(net, 100, activation='relu',name='second_fc')
#net = tf.fully_connected(net, 50, activation='relu',name='third_fc')
net = tf.fully_connected(net, 2, activation='softmax',name='output')
net = tf.regression(net, optimizer='adam', learning_rate=0.001,
                         loss='categorical_crossentropy')

model = tf.DNN(net, tensorboard_verbose=0,checkpoint_path='/tmp/tflearn_logs/model/model.tfl.ckpt')

# %%
from tensorflow.contrib.tensorboard.plugins import projector
# Use the same LOG_DIR where you stored your checkpoint.
summary_writer = tensorflow.summary.FileWriter('/tmp/tflearn_logs/model/')

# Format: tensorflow/contrib/tensorboard/plugins/projector/projector_config.proto
config = projector.ProjectorConfig()

# You can add multiple embeddings. Here we add only one.
embedding = config.embeddings.add()
embedding.tensor_name = 'embedded_layer/W'
# Link this tensor to its metadata file (e.g. labels).
pd.Series(features).to_csv('/tmp/tflearn_logs/model/metadata.tsv',sep='\n',index=False,header=False)

embedding.metadata_path = '/tmp/tflearn_logs/model/metadata.tsv'



# Saves a configuration file that TensorBoard will read during startup.
projector.visualize_embeddings(summary_writer, config)

# %%
#model.save('/tmp/tflearn_logs/model/model_saved.ckpt')
model.fit(trainX, trainY,validation_set=(testX,testY), run_id='model',n_epoch=20, batch_size=64,show_metric=True,snapshot_step=10000,snapshot_epoch=True)
model.save('/tmp/tflearn_logs/model/model_saved.ckpt')
# Out:
# Training Step: 95999  | total loss: 0.24044 | time: 610.681s
# | Adam | epoch: 004 | loss: 0.24044 - acc: 0.8885 -- iter: 0143936/2000000
# Training Step: 96000  | total loss: 0.24461 | time: 760.254s
# | Adam | epoch: 004 | loss: 0.24461 - acc: 0.8903 | val_loss: 0.34700 - val_acc: 0.8523 -- iter: 0144000/2000000
# --
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: /tmp/tflearn_logs/model/model.tfl.ckpt-96000.data-00000-of-00001.tempstate14484930449380569016; No space left on device
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_BOOL, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Accuracy/Mean/moving_avg/_111, Adam/beta1_power/_113, Adam/beta2_power/_115, Crossentropy/Mean/moving_avg/_117, Global_Step/_119, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/_121, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam/_123, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam_1/_125, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/_127, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam/_129, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam_1/_131, LSTM_layer/LSTM_layer/is_training, Training_step/_133, embedded_layer/W, embedded_layer/W/Adam, embedded_layer/W/Adam_1, output/W/_135, output/W/Adam/_137, output/W/Adam_1/_139, output/b/_141, output/b/Adam/_143, output/b/Adam_1/_145, val_acc/_147, val_loss/_149)]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-18-76458c55c970> in <module>()
#       1 #model.save('/tmp/tflearn_logs/model/model_saved.ckpt')
# ----> 2 model.fit(trainX, trainY,validation_set=(testX,testY), run_id='model',n_epoch=20, batch_size=64,show_metric=True,snapshot_step=1000,snapshot_epoch=True)
#       3 model.save('/tmp/tflearn_logs/model/model_saved.ckpt')
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/models/dnn.py in fit(self, X_inputs, Y_targets, n_epoch, validation_set, show_metric, batch_size, shuffle, snapshot_epoch, snapshot_step, excl_trainops, validation_batch_size, run_id, callbacks)
#     214                          excl_trainops=excl_trainops,
#     215                          run_id=run_id,
# --> 216                          callbacks=callbacks)
#     217
#     218     def fit_batch(self, X_inputs, Y_targets):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/helpers/trainer.py in fit(self, feed_dicts, n_epoch, val_feed_dicts, show_metric, snapshot_step, snapshot_epoch, shuffle_all, dprep_dict, daug_dict, excl_trainops, run_id, callbacks)
#     346                         # All optimizers batch end
#     347                         self.session.run(self.incr_global_step)
# --> 348                         caller.on_batch_end(self.training_state, snapshot)
#     349
#     350                     # Epoch end
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/callbacks.py in on_batch_end(self, training_state, snapshot)
#      74     def on_batch_end(self, training_state, snapshot=False):
#      75         for callback in self.callbacks:
# ---> 76             callback.on_batch_end(training_state, snapshot)
#      77
#      78     def on_epoch_end(self, training_state):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/callbacks.py in on_batch_end(self, training_state, snapshot)
#     281
#     282         if snapshot & (self.snapshot_step is not None):
# --> 283             self.save(training_state.step)
#     284
#     285         if None not in (self.best_snapshot_path, self.best_val_accuracy, training_state.val_acc):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/callbacks.py in save(self, training_step)
#     302     def save(self, training_step=0):
#     303         if self.snapshot_path:
# --> 304             self.save_func(self.snapshot_path, training_step)
#     305
#     306     def save_best(self, val_accuracy):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/helpers/trainer.py in save(self, model_file, global_step)
#     411         if not os.path.isabs(model_file):
#     412             model_file = os.path.abspath(os.path.join(os.getcwd(), model_file))
# --> 413         self.saver.save(self.session, model_file, global_step=global_step)
#     414         utils.fix_saver(obj_lists)
#     415
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1571           model_checkpoint_path = sess.run(
#    1572               self.saver_def.save_tensor_name,
# -> 1573               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1574         else:
#    1575           self._build_eager(
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# ResourceExhaustedError: /tmp/tflearn_logs/model/model.tfl.ckpt-96000.data-00000-of-00001.tempstate14484930449380569016; No space left on device
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_BOOL, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Accuracy/Mean/moving_avg/_111, Adam/beta1_power/_113, Adam/beta2_power/_115, Crossentropy/Mean/moving_avg/_117, Global_Step/_119, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/_121, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam/_123, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam_1/_125, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/_127, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam/_129, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam_1/_131, LSTM_layer/LSTM_layer/is_training, Training_step/_133, embedded_layer/W, embedded_layer/W/Adam, embedded_layer/W/Adam_1, output/W/_135, output/W/Adam/_137, output/W/Adam_1/_139, output/b/_141, output/b/Adam/_143, output/b/Adam_1/_145, val_acc/_147, val_loss/_149)]]
#
# Caused by op 'save/SaveV2', defined at:
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-26d092d7550e>", line 15, in <module>
#     model = tf.DNN(net, tensorboard_verbose=0,checkpoint_path='/tmp/tflearn_logs/model/model.tfl.ckpt')
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/models/dnn.py", line 65, in __init__
#     best_val_accuracy=best_val_accuracy)
#   File "/home/keshav/anaconda3/envs/py35/lib/python3.5/site-packages/tflearn/helpers/trainer.py", line 137, in __init__
#     allow_empty=True)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1218, in __init__
#     self.build()
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1227, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1263, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 748, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 296, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 239, in save_op
#     tensors)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1163, in save_v2
#     shape_and_slices=shape_and_slices, tensors=tensors, name=name)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/home/keshav/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): /tmp/tflearn_logs/model/model.tfl.ckpt-96000.data-00000-of-00001.tempstate14484930449380569016; No space left on device
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_BOOL, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, Accuracy/Mean/moving_avg/_111, Adam/beta1_power/_113, Adam/beta2_power/_115, Crossentropy/Mean/moving_avg/_117, Global_Step/_119, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/_121, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam/_123, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Bias/Adam_1/_125, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/_127, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam/_129, LSTM_layer/LSTM_layer/BasicLSTMCell/Linear/Matrix/Adam_1/_131, LSTM_layer/LSTM_layer/is_training, Training_step/_133, embedded_layer/W, embedded_layer/W/Adam, embedded_layer/W/Adam_1, output/W/_135, output/W/Adam/_137, output/W/Adam_1/_139, output/b/_141, output/b/Adam/_143, output/b/Adam_1/_145, val_acc/_147, val_loss/_149)]]

# %%
np.max(X)

# %%
num_vocab
# Out:
# 88922

# %%
trainX.shape

# %%
import pickle

# %%
pickle.dump([trainX,trainY,testX,testY,X_test,num_vocab],open('train_test_full_test','wb'))

# %%
a,b,c,d,full=pickle.load(open('train_test_full','rb'))

# %%
full
# Out:
# 88922

# %%
train
